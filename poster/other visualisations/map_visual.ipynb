# %%
# libraries 
import pandas as pd

# %%
df_map = pd.read_csv("../cleaned_data/cleaning_data-02.csv") 

df_map.head() #D1A_6AF: Internal: District of destination - First, Head
# Out:
#    BEM_ID  P_IDCOR  H_IDNUMBER    HHNO  PERSNO  RELHEAD  A03  A07     A08  \
# 0     203      NaN         NaN  3169.0       3      3.0  2.0  1.0  2004.0
# 1     203      NaN         NaN  3169.0       4      3.0  2.0  1.0  2012.0
# 2     203      NaN         NaN  3169.0       5      3.0  1.0  1.0  2016.0
# 3     203      NaN         NaN  3169.0       2      2.0  2.0  1.0  1985.0
# 4     203      NaN         NaN  3169.0       1      1.0  1.0  2.0  1979.0
#
#    A09  ...  G2_5B1S1  G2_6S1  G2_7S1  DISTRICT  D1A_10AF_3M  D1A_10AL_3M  \
# 0  NaN  ...       NaN     NaN     NaN       4.0          NaN          NaN
# 1  NaN  ...       NaN     NaN     NaN       4.0          NaN          NaN
# 2  NaN  ...       NaN     NaN     NaN       4.0          NaN          NaN
# 3  NaN  ...       NaN     NaN     NaN       4.0          NaN          NaN
# 4  NaN  ...       NaN     NaN     NaN       4.0          NaN          NaN
#
#    D1C_10AF_3M  D1C_10AL_3M  A05  MOUZA_GRP
# ...

# %%
# Print unique values in the 'D1A_6AF' column
print("Unique values in the 'D1A_6AF' column:")
print(df_map['D1A_6AF'].unique())
# Out:
# Unique values in the 'D1A_6AF' column:
# [nan 86. 59. 26. 33. 58. 13. 15. 67. 42.  6. 47. 94. 55. 41. 46.  4. 69.
#  68.  9.  1. 87.  3. 91. 78. 75. 35. 79. 65. 29. 61. 54. 22. 30. 81. 51.
#  19. 93. 10. 50. 39. 44. 36. 70. 18. 82. 56. 85. 73. 76. 32. 88. 27. 72.
#  48. 57. 84. 12.]

# %%
# Filter out rows where 'D1A_6AF' is not null
df_filtered = df_map[df_map['D1A_6AF'].notnull()]

# %%
import folium
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut, GeocoderUnavailable

# Read the CSV file into a DataFrame
df_map = pd.read_csv("../cleaned_data/cleaning_data-02.csv")

# Filter out rows where 'D1A_6AF' is not null
df_filtered = df_map[df_map['D1A_6AF'].notnull()]

# Initialize a geocoder
geolocator = Nominatim(user_agent="my_geocoder")

# Create a map centered around Bangladesh
m = folium.Map(location=[23.6850, 90.3563], zoom_start=7)

# Add points to the map for each district
for index, row in df_filtered.iterrows():
    # Retry geocoding a few times if there's a timeout or service unavailable error
    for _ in range(3):
        try:
            # Geocode the district name
            location = geolocator.geocode(row['D1A_6AF'])
            if location:
                folium.Marker(location=[location.latitude, location.longitude], popup=row['D1A_6AF']).add_to(m)
            break  # Break out of retry loop if successful
        except (GeocoderTimedOut, GeocoderUnavailable):
            continue  # Retry if there's a timeout or service unavailable error

# Display the map
m
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 24
#      21 for _ in range(3):
#      22     try:
#      23         # Geocode the district name
# ---> 24         location = geolocator.geocode(row['D1A_6AF'])
#      25         if location:
#      26             folium.Marker(location=[location.latitude, location.longitude], popup=row['D1A_6AF']).add_to(m)
#
# File ~/miniforge3/envs/gu/lib/python3.10/site-packages/geopy/geocoders/nominatim.py:297, in Nominatim.geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     295 logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     296 callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 297 return self._call_geocoder(url, callback, timeout=timeout)
#
# ...
